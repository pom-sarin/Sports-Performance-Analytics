# %% [markdown]
# ## From Run Expectancy to Wins Above Replacement (WAR)
#
# The Run Expectancy Matrix is a context-dependent measure of productivity. By introducing the context of a hit or a walk to the state of the game, it provides a more accurate measure of the contribution of a position player.
#
# In the previous notebook we derived the Runs Value of an event, measured by the runs scored on the play, plus the Runs Expectancy at the end of the play minus the Run Expectancy at the beginning of the play. We also measured the season-long contribution of the position player as the sum of Runs Values across all plate appearances.
#
# The Run Expectancy Matrix has been used in recent years to develop new ways of valuing player contributions. Because the underlying data has not been easily available until recently, and because deriving the matrix from the data was not easy in the past, the Run Expectancy Matrix has been adapted in simple ways.
#
# In the previous notebooks we looked at On Base Percentage (OBP) and Slugging (SLG). In recent years an increasingly popular statistic for measuring performance has been On-base Plus Slugging (OPS). OPS = OBP + SLG (hence the name "On-base Plus Slugging"). This measure is useful since it recognizes both the value of getting on base and extra value of doubles, triples, and home runs.
#
# However, as a measure of contribution, it implicitly imposes equal weights on each element of the formula. Is a double worth exactly twice a single in terms of runs scored? We shouldn't assume that - we should let the data tell us. This is exactly the idea behind the use of "linear weights" to calculate weighted on-base average (wOBA). The linear weights are taken from the Run Expectancy Matrix.
#
# There are different versions of wOBA out there depending on different adjustments preferred by different analysts. Remember that the Run Expectancy Matrix changes from year to year, and hence analysts like to evaluate a player relative to the RE Matrix of the season from which their stats are derived.
#
# For example, Fangraphs, a popular baseball statistics site, defined the following formula for wOBA in 2018:
#
# wOBA = (0.69*NIBB + 0.72*HBP + 0.88*1B + 1.247*2B + 1.578*3B + 2.031*HR)/(AB + BB - IBB +SF + HBP)
#
# where NIBB and IBB are non-intentional and intentional walks.
#
# The weights in wOBA are taken from the Run Expectancy Matrix. Sites such as Fangraphs and Baseball Reference generate these statistics, and then use the coefficients to generate measures such as wOBA, which they consider an improvement on On-base Plus Slugging (OPS).
#
# To take this further, analysts have created statistics to account for the total contribution of a player, one of the most popular being Wins Above Replacement (WAR). Most measures of WAR are based around calculations of wOBA for position players. We can summarize three aims in the creation of these statistics:
#
# >(i) To account for the four dimensions of on-field performance - batting, base-running, pitching, and fielding. The first two constitute offense, the last two defense. While base-running and fielding make a difference, it is batting and pitching which generate most value added in the game. One can think of pitching, in terms of the Run Expectancy Matrix, as the opposite of batting- if a play generates a positive Run Value for the batter, it creates an equal and opposite Run Value for the pitcher.
#
# >(ii) To adjust for differences in productivity which are unrelated to the skill of the player. The obvious adjustment here is for the size of the ballpark- some are easier for offense than than others, so player stats can be adjusted to take account of these differences. More subtly, a left-handed batter has an advantage over a right-handed batter when facing a right-handed pitcher - the so-called "Platoon Effect" - this advantage is often calculated and then deducted from the batter's Run Value.
#
# >(iii) To express the value of a player relative to a replacement player. If a player is injured, the team typically brings up a player from the minor leagues. Thus the true value of a player is his productivity relative to this likely replacement. Replacement value is usually calculated by averaging the statistics of players with a small number of appearances over the season, since these players are likely to be similar to players called up from the minors.
#
#
# So far we have measured performance in terms of runs. For ease of interpretation (only), WAR is expressed in terms of wins, where a win is typically valued at around ten wins.
#
# In what follows we're going to focus only on batting (which is essentially offensive WAR) and ignore all of the adjustments. Not adjusting the figures might reduce their reliability, but our use of the RE Matrix has one big advantage over WAR based on wOBA. While Run Expectancy takes into account the context of an event, the linear weights are applied to average performance statistics over the season and are therefore not context dependent. Since we have the Run Expectancy Matrix to work with, our performance stats are context dependent.

# %% [markdown]
# # Runs Values
#
# Here we are going to look at the seasons 2016 and 2017. As ever, we begin by loading the packages we need.

# %%
#Load packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Writing a Function to Create the Runs Value of Each Event in a Season
#
# In the previous workbook we used the MLBAM data for 2018 to derive the Run Expectancy Matrix and then create the Runs Value of every event. MLBAM has made available files in the same format for each season since 2014. Because the files are structured identically with identical names, we can turn the code into a Python function to produce the RE Matrix and Runs Values for any season, depending on the the file we choose.
#
# The function always starts with 'def'. Here the name Run_Expectancy is given to it, and it is defined by a path, which is where the data is to be found on which to execute the function. The content of the function (which must be indented) is simply a copy of all the lines of code used in the previous notebook, the only difference now is that the specific name 'MLBAM18' is replaced with a generic name 'RE', while the actual name applied when the function is run is defined when we specify the path. The function is completed by specifying 'return', the name of the output and a semi colon (;).

# %%
def Run_Expectancy(path):
    
    RE = pd.read_csv(path)
    RE.drop(['Unnamed: 0'], axis=1, inplace=True)
    RE = RE[['home_team','away_team','half','gameId','batterName','batterId','event', 'start1B', 'start2B', 'start3B',\
             'end1B', 'end2B', 'end3B', 'startOuts','endOuts','runsFuture','runsOnPlay','outsInInning','venueId','batterPos']]
    RE['Start1'] = np.where(pd.isnull(RE['start1B']),0,1)
    RE['Start2'] = np.where(pd.isnull(RE['start2B']),0,1)
    RE['Start3'] = np.where(pd.isnull(RE['start3B']),0,1)
    RE['Start_State'] = (RE['Start1'].astype(str) + RE['Start2'].astype(str) + RE['Start3'].astype(str)+\
                          " " + RE['startOuts'].astype(str))
    RE['End1'] = np.where(pd.isnull(RE['end1B']),0,1)
    RE['End2'] = np.where(pd.isnull(RE['end2B']),0,1)
    RE['End3'] = np.where(pd.isnull(RE['end3B']),0,1)
    RE['End_State'] = (RE['End1'].astype(str) + RE['End2'].astype(str) + RE['End3'].astype(str) + \
                        " " + RE['endOuts'].astype(str))
    RE = RE[((RE.Start_State != RE.End_State) | (RE.runsOnPlay > 0)) & (RE.outsInInning == 3)]
    Start_RunExp = RE.groupby(['Start_State'])['runsFuture'].mean().reset_index().rename(columns={'runsFuture':'Start_RE'})
    RE = pd.merge(RE, Start_RunExp, on=['Start_State'], how='left')
    Base_State_3 = [pd.Series(['000 3', 0], index=Start_RunExp.columns),
                pd.Series(['001 3', 0], index=Start_RunExp.columns),
                pd.Series(['010 3', 0], index=Start_RunExp.columns),
                pd.Series(['011 3', 0], index=Start_RunExp.columns),
                pd.Series(['100 3', 0], index=Start_RunExp.columns),
                pd.Series(['101 3', 0], index=Start_RunExp.columns),
                pd.Series(['110 3', 0], index=Start_RunExp.columns),
                pd.Series(['111 3', 0], index=Start_RunExp.columns)]
    Start_RunExp = Start_RunExp.append(Base_State_3, ignore_index=True)
    End_RunExp  = Start_RunExp.rename(columns={'Start_State':'End_State', 'Start_RE':'End_RE'})
    RE = pd.merge(RE, End_RunExp, on=['End_State'], how='left')
    RE['Run_Value'] = RE['runsOnPlay'] + RE['End_RE'] - RE['Start_RE']
    
    return RE;

# %% [markdown]
# ## Applying the Function Using 2017 Data
#
# We now specify the path (file location) used to run Run_Expectancy for 2017, and give the output the name RE_17.

# %%
RE_17 = Run_Expectancy("../Data/MLBAM17.csv")                          
display(RE_17)
# Out:
#        home_team away_team    half                          gameId  \
# 0            tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 1            tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 2            tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 3            tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 4            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 5            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 6            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 7            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 8            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 9            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 10           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 11           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 12           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 13           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 14           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 15           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 16           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 17           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 18           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 19           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 20           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 21           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 22           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 23           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 24           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 25           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 26           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 27           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 28           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 29           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# ...          ...       ...     ...                             ...
# 184721       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184722       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184723       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184724       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184725       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184726       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184727       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184728       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184729       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184730       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184731       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184732       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184733       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184734       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184735       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184736       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184737       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184738       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184739       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184740       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184741       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184742       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184743       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184744       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184745       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184746       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184747       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184748       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184749       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184750       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
#
#           batterName  batterId       event   start1B   start2B   start3B  ...  \
# 0            Gardner    458731      Flyout       NaN       NaN       NaN  ...
# 1         Sanchez, G    596142   Groundout       NaN       NaN       NaN  ...
# 2               Bird    595885        Walk       NaN       NaN       NaN  ...
# 3           Holliday    407812   Groundout  595885.0       NaN       NaN  ...
# 4       Dickerson, C    572816      Single       NaN       NaN       NaN  ...
# 5          Kiermaier    595281      Double  572816.0       NaN       NaN  ...
# 6           Longoria    446334     Sac Fly       NaN  595281.0  572816.0  ...
# 7          Miller, B    543543      Single       NaN  595281.0       NaN  ...
# 8          Souza Jr.    519306        Walk  543543.0       NaN  595281.0  ...
# 9           Morrison    489149      Single  519306.0  543543.0  595281.0  ...
# 10           Beckham    542921     Lineout  489149.0  519306.0       NaN  ...
# 11          Smith, M    605480   Strikeout  489149.0  519306.0       NaN  ...
# 12          Ellsbury    453056      Flyout       NaN       NaN       NaN  ...
# 13         Castro, S    516770      Single       NaN       NaN       NaN  ...
# 14           Headley    452104      Single  516770.0       NaN       NaN  ...
# 15             Judge    592450      Double  452104.0  516770.0       NaN  ...
# 16          Torreyes    591720   Groundout       NaN  592450.0  452104.0  ...
# 17           Gardner    458731   Groundout       NaN       NaN  592450.0  ...
# 18        Norris, De    519083   Groundout       NaN       NaN       NaN  ...
# 19      Dickerson, C    572816   Strikeout       NaN       NaN       NaN  ...
# 20         Kiermaier    595281        Walk       NaN       NaN       NaN  ...
# 21          Longoria    446334    Home Run  595281.0       NaN       NaN  ...
# 22         Miller, B    543543      Flyout       NaN       NaN       NaN  ...
# 23        Sanchez, G    596142   Groundout       NaN       NaN       NaN  ...
# 24              Bird    595885      Flyout       NaN       NaN       NaN  ...
# 25          Holliday    407812   Strikeout       NaN       NaN       NaN  ...
# 26         Souza Jr.    519306   Strikeout       NaN       NaN       NaN  ...
# 27          Morrison    489149    Home Run       NaN       NaN       NaN  ...
# 28           Beckham    542921      Double       NaN       NaN       NaN  ...
# 29          Smith, M    605480      Single       NaN  542921.0       NaN  ...
# ...              ...       ...         ...       ...       ...       ...  ...
# 184721        Duvall    594807      Double       NaN       NaN       NaN  ...
# 184722        Suarez    553993      Single       NaN  594807.0       NaN  ...
# 184723       Gennett    571697      Single  553993.0       NaN  594807.0  ...
# 184724         Ervin    640447     Lineout  571697.0  553993.0       NaN  ...
# 184725       Wallach    595453   Strikeout  571697.0  553993.0       NaN  ...
# 184726      Davis, T    543089      Flyout       NaN       NaN       NaN  ...
# 184727    Almora Jr.    546991   Groundout       NaN       NaN       NaN  ...
# 184728       Freeman    502273   Groundout       NaN       NaN       NaN  ...
# 184729      Kivlehan    623182   Groundout       NaN       NaN       NaN  ...
# 184730      Hamilton    571740     Lineout       NaN       NaN       NaN  ...
# 184731        Vincej    572227   Strikeout       NaN       NaN       NaN  ...
# 184732       Zobrist    450314   Strikeout       NaN       NaN       NaN  ...
# 184733      Pena, Fe    570240   Strikeout       NaN       NaN       NaN  ...
# 184734     Schwarber    656941   Groundout       NaN       NaN       NaN  ...
# 184735         Votto    458015      Double       NaN       NaN       NaN  ...
# 184736        Duvall    594807   Strikeout       NaN  458015.0       NaN  ...
# 184737        Suarez    553993      Flyout       NaN  458015.0       NaN  ...
# 184738       Gennett    571697   Strikeout       NaN  458015.0       NaN  ...
# 184739      Caratini    605170   Strikeout       NaN       NaN       NaN  ...
# 184740     La Stella    600303   Strikeout       NaN       NaN       NaN  ...
# 184741       Happ, I    664023   Strikeout       NaN       NaN       NaN  ...
# 184742         Ervin    640447      Flyout       NaN       NaN       NaN  ...
# 184743       Wallach    595453   Strikeout       NaN       NaN       NaN  ...
# 184744        Winker    608385      Single       NaN       NaN       NaN  ...
# 184745      Hamilton    571740        Walk  608385.0       NaN       NaN  ...
# 184746        Vincej    572227  Runner Out  571740.0  608385.0       NaN  ...
# 184747      Davis, T    543089   Groundout       NaN       NaN       NaN  ...
# 184748    Almora Jr.    546991    Home Run       NaN       NaN       NaN  ...
# 184749       Freeman    502273   Groundout       NaN       NaN       NaN  ...
# 184750       Zobrist    450314   Groundout       NaN       NaN       NaN  ...
#
#         Start2  Start3  Start_State  End1  End2  End3  End_State  Start_RE  \
# 0            0       0        000 0     0     0     0      000 1  0.516375
# 1            0       0        000 1     0     0     0      000 2  0.272176
# 2            0       0        000 2     1     0     0      100 2  0.108038
# 3            0       0        100 2     0     0     0      000 3  0.225365
# 4            0       0        000 0     1     0     0      100 0  0.516375
# 5            0       0        100 0     0     1     1      011 0  0.912921
# 6            1       1        011 0     0     1     0      010 1  2.051376
# 7            1       0        010 1     1     0     1      101 1  0.711650
# 8            0       1        101 1     1     1     1      111 1  1.215306
# 9            1       1        111 1     1     1     0      110 1  1.635608
# 10           1       0        110 1     1     1     0      110 2  0.947424
# 11           1       0        110 2     0     0     0      000 3  0.449782
# 12           0       0        000 0     0     0     0      000 1  0.516375
# 13           0       0        000 1     1     0     0      100 1  0.272176
# 14           0       0        100 1     1     1     0      110 1  0.524904
# 15           1       0        110 1     0     1     1      011 1  0.947424
# 16           1       1        011 1     0     0     1      001 2  1.517131
# 17           0       1        001 2     0     0     0      000 3  0.381186
# 18           0       0        000 0     0     0     0      000 1  0.516375
# 19           0       0        000 1     0     0     0      000 2  0.272176
# 20           0       0        000 2     1     0     0      100 2  0.108038
# 21           0       0        100 2     0     0     0      000 2  0.225365
# 22           0       0        000 2     0     0     0      000 3  0.108038
# 23           0       0        000 0     0     0     0      000 1  0.516375
# 24           0       0        000 1     0     0     0      000 2  0.272176
# 25           0       0        000 2     0     0     0      000 3  0.108038
# 26           0       0        000 0     0     0     0      000 1  0.516375
# 27           0       0        000 1     0     0     0      000 1  0.272176
# 28           0       0        000 1     0     1     0      010 1  0.272176
# 29           1       0        010 1     0     1     0      010 1  0.711650
# ...        ...     ...          ...   ...   ...   ...        ...       ...
# 184721       0       0        000 1     0     1     0      010 1  0.272176
# 184722       1       0        010 1     1     0     1      101 1  0.711650
# 184723       0       1        101 1     1     1     0      110 1  1.215306
# 184724       1       0        110 1     1     1     0      110 2  0.947424
# 184725       1       0        110 2     0     0     0      000 3  0.449782
# 184726       0       0        000 0     0     0     0      000 1  0.516375
# 184727       0       0        000 1     0     0     0      000 2  0.272176
# 184728       0       0        000 2     0     0     0      000 3  0.108038
# 184729       0       0        000 0     0     0     0      000 1  0.516375
# 184730       0       0        000 1     0     0     0      000 2  0.272176
# 184731       0       0        000 2     0     0     0      000 3  0.108038
# 184732       0       0        000 0     0     0     0      000 1  0.516375
# 184733       0       0        000 1     0     0     0      000 2  0.272176
# 184734       0       0        000 2     0     0     0      000 3  0.108038
# 184735       0       0        000 0     0     1     0      010 0  0.516375
# 184736       1       0        010 0     0     1     0      010 1  1.154829
# 184737       1       0        010 1     0     1     0      010 2  0.711650
# 184738       1       0        010 2     0     0     0      000 3  0.336702
# 184739       0       0        000 0     0     0     0      000 1  0.516375
# 184740       0       0        000 1     0     0     0      000 2  0.272176
# 184741       0       0        000 2     0     0     0      000 3  0.108038
# 184742       0       0        000 0     0     0     0      000 1  0.516375
# 184743       0       0        000 1     0     0     0      000 2  0.272176
# 184744       0       0        000 2     1     0     0      100 2  0.108038
# 184745       0       0        100 2     1     1     0      110 2  0.225365
# 184746       1       0        110 2     0     0     0      000 3  0.449782
# 184747       0       0        000 0     0     0     0      000 1  0.516375
# 184748       0       0        000 1     0     0     0      000 1  0.272176
# 184749       0       0        000 1     0     0     0      000 2  0.272176
# 184750       0       0        000 2     0     0     0      000 3  0.108038
#
#           End_RE Run_Value
# 0       0.272176 -0.244199
# 1       0.108038 -0.164138
# 2       0.225365  0.117327
# 3       0.000000 -0.225365
# 4       0.912921  0.396546
# 5       2.051376  1.138455
# 6       0.711650 -0.339727
# 7       1.215306  0.503657
# 8       1.635608  0.420302
# 9       0.947424  1.311816
# 10      0.449782 -0.497642
# 11      0.000000 -0.449782
# 12      0.272176 -0.244199
# 13      0.524904  0.252728
# 14      0.947424  0.422520
# 15      1.517131  1.569707
# 16      0.381186 -0.135945
# 17      0.000000 -0.381186
# 18      0.272176 -0.244199
# 19      0.108038 -0.164138
# 20      0.225365  0.117327
# 21      0.108038  1.882673
# 22      0.000000 -0.108038
# 23      0.272176 -0.244199
# 24      0.108038 -0.164138
# 25      0.000000 -0.108038
# 26      0.272176 -0.244199
# 27      0.272176  1.000000
# 28      0.711650  0.439473
# 29      0.711650  1.000000
# ...          ...       ...
# 184721  0.711650  0.439473
# 184722  1.215306  0.503657
# 184723  0.947424  0.732118
# 184724  0.449782 -0.497642
# 184725  0.000000 -0.449782
# 184726  0.272176 -0.244199
# 184727  0.108038 -0.164138
# 184728  0.000000 -0.108038
# 184729  0.272176 -0.244199
# 184730  0.108038 -0.164138
# 184731  0.000000 -0.108038
# 184732  0.272176 -0.244199
# 184733  0.108038 -0.164138
# 184734  0.000000 -0.108038
# 184735  1.154829  0.638454
# 184736  0.711650 -0.443179
# 184737  0.336702 -0.374947
# 184738  0.000000 -0.336702
# 184739  0.272176 -0.244199
# 184740  0.108038 -0.164138
# 184741  0.000000 -0.108038
# 184742  0.272176 -0.244199
# 184743  0.108038 -0.164138
# 184744  0.225365  0.117327
# 184745  0.449782  0.224418
# 184746  0.000000 -0.449782
# 184747  0.272176 -0.244199
# 184748  0.272176  1.000000
# 184749  0.108038 -0.164138
# 184750  0.000000 -0.108038
#
# [184751 rows x 31 columns]

# %% [markdown]
# ## We Now Repeat the Same Exercise for 2016

# %%
RE_16 = Run_Expectancy("../Data/MLBAM16.csv")                          
display(RE_16)
# Out:
#        home_team away_team    half                          gameId  \
# 0            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 1            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 2            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 3            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 4            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 5            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 6            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 7            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 8            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 9            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 10           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 11           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 12           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 13           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 14           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 15           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 16           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 17           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 18           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 19           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 20           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 21           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 22           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 23           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 24           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 25           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 26           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 27           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 28           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 29           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# ...          ...       ...     ...                             ...
# 184122       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184123       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184124       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184125       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184126       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184127       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184128       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184129       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184130       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184131       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184132       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184133       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184134       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184135       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184136       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184137       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184138       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184139       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184140       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184141       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184142       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184143       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184144       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184145       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184146       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184147       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184148       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184149       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184150       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184151       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
#
#           batterName  batterId             event   start1B   start2B  \
# 0       Carpenter, M    572761         Groundout       NaN       NaN
# 1               Pham    502054         Groundout       NaN       NaN
# 2           Holliday    407812         Strikeout       NaN       NaN
# 3               Jaso    444379         Groundout       NaN       NaN
# 4          McCutchen    457705      Hit By Pitch       NaN       NaN
# 5             Freese    501896            Single  457705.0       NaN
# 6           Marte, S    516782           Lineout  501896.0       NaN
# 7           Cervelli    465041           Pop Out  501896.0       NaN
# 8            Grichuk    545341         Strikeout       NaN       NaN
# 9           Piscotty    572039         Strikeout       NaN       NaN
# 10            Molina    425877         Strikeout       NaN       NaN
# 11        Polanco, G    570256            Double       NaN       NaN
# 12          Harrison    543281         Groundout       NaN  570256.0
# 13            Mercer    474568              Walk       NaN       NaN
# 14           Liriano    434538            Single  474568.0       NaN
# 15              Jaso    444379            Single  434538.0  474568.0
# 16         McCutchen    457705            Flyout  444379.0  434538.0
# 17            Freese    501896         Groundout  444379.0  434538.0
# 18              Wong    543939         Strikeout       NaN       NaN
# 19            Gyorko    576397              Walk       NaN       NaN
# 20        Wainwright    425794       Field Error  576397.0       NaN
# 21      Carpenter, M    572761  Grounded Into DP  425794.0       NaN
# 22          Marte, S    516782           Lineout       NaN       NaN
# 23          Cervelli    465041              Walk       NaN       NaN
# 24        Polanco, G    570256            Flyout  465041.0       NaN
# 25          Harrison    543281         Strikeout  465041.0       NaN
# 26             Adams    571431         Strikeout       NaN       NaN
# 27          Holliday    407812            Single       NaN       NaN
# 28           Grichuk    545341            Single  407812.0       NaN
# 29          Piscotty    572039         Strikeout  545341.0  407812.0
# ...              ...       ...               ...       ...       ...
# 184122       Grichuk    545341         Strikeout  576397.0       NaN
# 184123  Martinez, Jo    500874            Single  576397.0       NaN
# 184124  Carpenter, M    572761          Home Run  500874.0  576397.0
# 184125       Diaz, A    649557         Strikeout       NaN       NaN
# 184126    Frazier, A    624428            Single       NaN       NaN
# 184127          Jaso    444379          Home Run  624428.0       NaN
# 184128    Polanco, G    570256         Strikeout       NaN       NaN
# 184129     McCutchen    457705            Flyout       NaN       NaN
# 184130          Kang    628356         Strikeout       NaN       NaN
# 184131        Molina    425877            Double       NaN       NaN
# 184132      Piscotty    572039            Single       NaN  425877.0
# 184133    Peralta, J    425509            Single  572039.0       NaN
# 184134          Moss    461235            Single  425509.0  572039.0
# 184135        Gyorko    576397       Field Error  461235.0  425509.0
# 184136       Grichuk    545341            Double  576397.0  461235.0
# 184137         Adams    571431           Sac Fly       NaN  545341.0
# 184138  Carpenter, M    572761           Sac Fly       NaN       NaN
# 184139       Diaz, A    649557           Pop Out       NaN       NaN
# 184140         Joyce    459964         Groundout       NaN       NaN
# 184141        Hanson    593700            Flyout       NaN       NaN
# 184142         Fryer    518700            Single       NaN       NaN
# 184143      Florimon    465753         Groundout  518700.0       NaN
# 184144        Molina    425877         Groundout       NaN       NaN
# 184145      Piscotty    572039         Strikeout       NaN       NaN
# 184146     Garcia, G    594824            Single       NaN       NaN
# 184147          Moss    461235         Strikeout  594824.0       NaN
# 184148     Rogers, J    595386         Groundout       NaN       NaN
# 184149          Jaso    444379              Walk       NaN       NaN
# 184150    Polanco, G    570256         Strikeout  444379.0       NaN
# 184151     McCutchen    457705         Groundout  444379.0       NaN
#
#          start3B  ...  Start2  Start3  Start_State  End1  End2  End3  \
# 0            NaN  ...       0       0        000 0     0     0     0
# 1            NaN  ...       0       0        000 1     0     0     0
# 2            NaN  ...       0       0        000 2     0     0     0
# 3            NaN  ...       0       0        000 0     0     0     0
# 4            NaN  ...       0       0        000 1     1     0     0
# 5            NaN  ...       0       0        100 1     1     0     1
# 6       457705.0  ...       0       1        101 1     1     0     1
# 7       457705.0  ...       0       1        101 2     0     0     0
# 8            NaN  ...       0       0        000 0     0     0     0
# 9            NaN  ...       0       0        000 1     0     0     0
# 10           NaN  ...       0       0        000 2     0     0     0
# 11           NaN  ...       0       0        000 0     0     1     0
# 12           NaN  ...       1       0        010 0     0     0     1
# 13      570256.0  ...       0       1        001 1     1     0     1
# 14      570256.0  ...       0       1        101 1     1     1     0
# 15           NaN  ...       1       0        110 1     1     1     0
# 16           NaN  ...       1       0        110 1     1     1     0
# 17           NaN  ...       1       0        110 2     0     0     0
# 18           NaN  ...       0       0        000 0     0     0     0
# 19           NaN  ...       0       0        000 1     1     0     0
# 20           NaN  ...       0       0        100 1     1     0     1
# 21      576397.0  ...       0       1        101 1     0     0     0
# 22           NaN  ...       0       0        000 0     0     0     0
# 23           NaN  ...       0       0        000 1     1     0     0
# 24           NaN  ...       0       0        100 1     1     0     0
# 25           NaN  ...       0       0        100 2     0     0     0
# 26           NaN  ...       0       0        000 0     0     0     0
# 27           NaN  ...       0       0        000 1     1     0     0
# 28           NaN  ...       0       0        100 1     1     1     0
# 29           NaN  ...       1       0        110 1     1     1     0
# ...          ...  ...     ...     ...          ...   ...   ...   ...
# 184122       NaN  ...       0       0        100 1     1     0     0
# 184123       NaN  ...       0       0        100 2     1     1     0
# 184124       NaN  ...       1       0        110 2     0     0     0
# 184125       NaN  ...       0       0        000 2     0     0     0
# 184126       NaN  ...       0       0        000 0     1     0     0
# 184127       NaN  ...       0       0        100 0     0     0     0
# 184128       NaN  ...       0       0        000 0     0     0     0
# 184129       NaN  ...       0       0        000 1     0     0     0
# 184130       NaN  ...       0       0        000 2     0     0     0
# 184131       NaN  ...       0       0        000 0     0     1     0
# 184132       NaN  ...       1       0        010 0     1     0     0
# 184133       NaN  ...       0       0        100 0     1     1     0
# 184134       NaN  ...       1       0        110 0     1     1     1
# 184135  572039.0  ...       1       1        111 0     1     1     1
# 184136  425509.0  ...       1       1        111 0     0     1     1
# 184137  576397.0  ...       1       1        011 0     0     0     1
# 184138  545341.0  ...       0       1        001 1     0     0     0
# 184139       NaN  ...       0       0        000 2     0     0     0
# 184140       NaN  ...       0       0        000 0     0     0     0
# 184141       NaN  ...       0       0        000 1     0     0     0
# 184142       NaN  ...       0       0        000 2     1     0     0
# 184143       NaN  ...       0       0        100 2     0     0     0
# 184144       NaN  ...       0       0        000 0     0     0     0
# 184145       NaN  ...       0       0        000 1     0     0     0
# 184146       NaN  ...       0       0        000 2     1     0     0
# 184147       NaN  ...       0       0        100 2     0     0     0
# 184148       NaN  ...       0       0        000 0     0     0     0
# 184149       NaN  ...       0       0        000 1     1     0     0
# 184150       NaN  ...       0       0        100 1     1     0     0
# 184151       NaN  ...       0       0        100 2     0     0     0
#
#         End_State  Start_RE    End_RE Run_Value
# 0           000 1  0.498377  0.268678 -0.229699
# 1           000 2  0.268678  0.106305 -0.162373
# 2           000 3  0.106305  0.000000 -0.106305
# 3           000 1  0.498377  0.268678 -0.229699
# 4           100 1  0.268678  0.512225  0.243547
# 5           101 1  0.512225  1.196777  0.684552
# 6           101 2  1.196777  0.480175 -0.716603
# 7           000 3  0.480175  0.000000 -0.480175
# 8           000 1  0.498377  0.268678 -0.229699
# 9           000 2  0.268678  0.106305 -0.162373
# 10          000 3  0.106305  0.000000 -0.106305
# 11          010 0  0.498377  1.132468  0.634090
# 12          001 1  1.132468  0.948684 -0.183783
# 13          101 1  0.948684  1.196777  0.248093
# 14          110 1  1.196777  0.922572  0.725795
# 15          110 1  0.922572  0.922572  1.000000
# 16          110 2  0.922572  0.414466 -0.508107
# 17          000 3  0.414466  0.000000 -0.414466
# 18          000 1  0.498377  0.268678 -0.229699
# 19          100 1  0.268678  0.512225  0.243547
# 20          101 1  0.512225  1.196777  0.684552
# 21          000 3  1.196777  0.000000 -1.196777
# 22          000 1  0.498377  0.268678 -0.229699
# 23          100 1  0.268678  0.512225  0.243547
# 24          100 2  0.512225  0.220539 -0.291686
# 25          000 3  0.220539  0.000000 -0.220539
# 26          000 1  0.498377  0.268678 -0.229699
# 27          100 1  0.268678  0.512225  0.243547
# 28          110 1  0.512225  0.922572  0.410347
# 29          110 2  0.922572  0.414466 -0.508107
# ...           ...       ...       ...       ...
# 184122      100 2  0.512225  0.220539 -0.291686
# 184123      110 2  0.220539  0.414466  0.193926
# 184124      000 2  0.414466  0.106305  2.691840
# 184125      000 3  0.106305  0.000000 -0.106305
# 184126      100 0  0.498377  0.858504  0.360127
# 184127      000 0  0.858504  0.498377  1.639873
# 184128      000 1  0.498377  0.268678 -0.229699
# 184129      000 2  0.268678  0.106305 -0.162373
# 184130      000 3  0.106305  0.000000 -0.106305
# 184131      010 0  0.498377  1.132468  0.634090
# 184132      100 0  1.132468  0.858504  0.726037
# 184133      110 0  0.858504  1.447597  0.589092
# 184134      111 0  1.447597  2.112409  0.664812
# 184135      111 0  2.112409  2.112409  1.000000
# 184136      011 0  2.112409  1.916190  1.803782
# 184137      001 1  1.916190  0.948684  0.032494
# 184138      000 2  0.948684  0.106305  0.157621
# 184139      000 3  0.106305  0.000000 -0.106305
# 184140      000 1  0.498377  0.268678 -0.229699
# 184141      000 2  0.268678  0.106305 -0.162373
# 184142      100 2  0.106305  0.220539  0.114234
# 184143      000 3  0.220539  0.000000 -0.220539
# 184144      000 1  0.498377  0.268678 -0.229699
# 184145      000 2  0.268678  0.106305 -0.162373
# 184146      100 2  0.106305  0.220539  0.114234
# 184147      000 3  0.220539  0.000000 -0.220539
# 184148      000 1  0.498377  0.268678 -0.229699
# 184149      100 1  0.268678  0.512225  0.243547
# 184150      100 2  0.512225  0.220539 -0.291686
# 184151      000 3  0.220539  0.000000 -0.220539
#
# [184152 rows x 31 columns]

# %% [markdown]
# ## Self Test
#
# Repeat this exercise for the event data from 2015.

# %%
#Your Code Here

# %% [markdown]
# ## 1. Comparing Event Run Values
#
# To make comparisons between the two seasons we are going (a) use .groupby to generate a statistic for a particular variable (an event, a player, and a team) (b) merge the data for the two seasons (c) derive the correlation and, where suitable, create a scatter diagram.
#
# We start by comparing the Runs Value of events in each season.

# %%
#2016
Event_Value16= RE_16.groupby(['event'])['Run_Value'].mean().reset_index().rename(columns = {"Run_Value": 'RV16'})
Event_Value16
# Out:
#                    event      RV16
# 0    Batter Interference -0.284649
# 1         Bunt Groundout -0.218826
# 2           Bunt Lineout -0.352295
# 3           Bunt Pop Out -0.342802
# 4   Catcher Interference  0.301623
# 5                 Double  0.743467
# 6            Double Play -0.864981
# 7       Fan interference  0.533316
# 8            Field Error  0.469989
# 9        Fielders Choice  0.701447
# 10   Fielders Choice Out -0.610757
# 11                Flyout -0.247896
# 12              Forceout -0.326657
# 13      Grounded Into DP -0.773318
# 14             Groundout -0.212992
# 15          Hit By Pitch  0.320569
# 16              Home Run  1.382476
# 17           Intent Walk  0.172551
# 18               Lineout -0.248542
# 19               Pop Out -0.267062
# 20            Runner Out -0.257904
# 21              Sac Bunt -0.126691
# 22               Sac Fly  0.023233
# 23            Sac Fly DP -0.370443
# 24     Sacrifice Bunt DP -0.752199
# 25                Single  0.440258
# 26             Strikeout -0.259940
# 27        Strikeout - DP -0.622787
# 28                Triple  1.023911
# 29           Triple Play -1.637543
# 30                  Walk  0.299404

# %%
#2017
Event_Value17= RE_17.groupby(['event'])['Run_Value'].mean().reset_index().rename(columns = {"Run_Value": 'RV17'})
Event_Value17
# Out:
#                    event      RV17
# 0    Batter Interference -0.430019
# 1         Bunt Groundout -0.209411
# 2           Bunt Lineout -0.328292
# 3           Bunt Pop Out -0.373225
# 4   Catcher Interference  0.399070
# 5                 Double  0.779338
# 6            Double Play -0.897164
# 7       Fan interference  0.590743
# 8            Field Error  0.493206
# 9        Fielders Choice  0.764112
# 10   Fielders Choice Out -0.662400
# 11                Flyout -0.262548
# 12              Forceout -0.345347
# 13      Grounded Into DP -0.818005
# 14             Groundout -0.224579
# 15          Hit By Pitch  0.338679
# 16              Home Run  1.378739
# 17           Intent Walk  0.180109
# 18               Lineout -0.259682
# 19               Pop Out -0.283498
# 20            Runner Out -0.274991
# 21              Sac Bunt -0.109283
# 22               Sac Fly -0.032119
# 23            Sac Fly DP -0.543715
# 24                Single  0.455773
# 25             Strikeout -0.269985
# 26        Strikeout - DP -0.682819
# 27                Triple  1.063607
# 28           Triple Play -1.471223
# 29                  Walk  0.322635

# %%
# merge 2016 and 2017
RVseasons= pd.merge(Event_Value16,Event_Value17, on = ['event'])
RVseasons
# Out:
#                    event      RV16      RV17
# 0    Batter Interference -0.284649 -0.430019
# 1         Bunt Groundout -0.218826 -0.209411
# 2           Bunt Lineout -0.352295 -0.328292
# 3           Bunt Pop Out -0.342802 -0.373225
# 4   Catcher Interference  0.301623  0.399070
# 5                 Double  0.743467  0.779338
# 6            Double Play -0.864981 -0.897164
# 7       Fan interference  0.533316  0.590743
# 8            Field Error  0.469989  0.493206
# 9        Fielders Choice  0.701447  0.764112
# 10   Fielders Choice Out -0.610757 -0.662400
# 11                Flyout -0.247896 -0.262548
# 12              Forceout -0.326657 -0.345347
# 13      Grounded Into DP -0.773318 -0.818005
# 14             Groundout -0.212992 -0.224579
# 15          Hit By Pitch  0.320569  0.338679
# 16              Home Run  1.382476  1.378739
# 17           Intent Walk  0.172551  0.180109
# 18               Lineout -0.248542 -0.259682
# 19               Pop Out -0.267062 -0.283498
# 20            Runner Out -0.257904 -0.274991
# 21              Sac Bunt -0.126691 -0.109283
# 22               Sac Fly  0.023233 -0.032119
# 23            Sac Fly DP -0.370443 -0.543715
# 24                Single  0.440258  0.455773
# 25             Strikeout -0.259940 -0.269985
# 26        Strikeout - DP -0.622787 -0.682819
# 27                Triple  1.023911  1.063607
# 28           Triple Play -1.637543 -1.471223
# 29                  Walk  0.299404  0.322635

# %%
# the correlation coefficient
np.corrcoef(RVseasons.RV16,RVseasons.RV17)
# Out:
# array([[1.        , 0.99496361],
#        [0.99496361, 1.        ]])

# %% [markdown]
# ## Conclusion on Event Runs Value Comparison
#
# Although the exact Runs Value of an event can vary from year to year, the pattern of Runs Values across different events appear remarkably consistent,  with a +0.995 correlation coefficient.

# %% [markdown]
# ## Self Test
#
# Use the Run Expectancy data from 2015 to calculate the correlation coefficient for event Run Values comparing 2015 with 2017.

# %%
#Your Code Here

# %% [markdown]
# ## 2. Comparing Position Player Run Values
#
# We now repeat this comparison, grouping the data by player rather than by event. We use batterId as the matching variable, since each player has a unique number in the data, rather than batterName, since some players may have the same name.

# %%
Player_Value16 = RE_16.groupby(['batterId','batterName'])['Run_Value'].sum().reset_index().rename(columns = {"Run_Value": 'RV16'})
Player_Value16
# Out:
#      batterId     batterName       RV16
# 0      112526          Colon -15.380841
# 1      120074          Ortiz  60.938730
# 2      121347   Rodriguez, A -10.691410
# 3      134181         Beltre  29.745115
# 4      136860        Beltran  21.279393
# 5      150029          Werth   6.368448
# 6      150229     Pierzynski -17.583062
# 7      276519        Rollins  -7.574579
# 8      279571        Belisle  -0.481289
# 9      282332       Sabathia  -0.944580
# 10     285064      Vogelsong  -4.273891
# 11     285079         Dickey  -0.291686
# 12     346874          Uribe  -9.678935
# 13     400085      Suzuki, I  -2.577561
# 14     400121    Martinez, V   7.335464
# 15     400284          Utley   6.689794
# 16     405395         Pujols  15.581010
# 17     407781           Byrd   1.325310
# 18     407793         Lackey -14.016121
# 19     407812       Holliday  11.609729
# 20     407822  De La Rosa, J  -2.222822
# 21     407893       Teixeira -11.534686
# 22     407908    Peralta, Jo  -0.483502
# 23     408045          Mauer   3.738712
# 24     408047        Morneau  -2.162910
# 25     408234        Cabrera  37.520249
# 26     408234     Cabrera, M   0.085720
# 27     408236    Gonzalez, A  18.186314
# 28     408241          Peavy  -1.776060
# 29     408252       Phillips  -2.507057
# ..        ...            ...        ...
# 946    628452    Iglesias, R  -2.118223
# 947    628711          Urias  -2.416465
# 948    630111          Tomas   8.029901
# 949    640455         Manaea  -0.508653
# 950    640461         Pinder  -3.441069
# 951    640463        Shipley  -3.829643
# 952    641313   Anderson, Ti -11.022494
# 953    641319         Asuaje  -0.135144
# 954    641531      Dozier, H   0.629062
# 955    641771           Kuhl  -4.940016
# 956    641820        Mancini   3.565277
# 957    641958      Patterson   1.673196
# 958    642003           Reed  -2.960509
# 959    642162        Valaika  -1.942206
# 960    642229     Wright, Dn  -0.948062
# 961    642239      Zastryzny  -1.046863
# 962    643217     Benintendi   7.762445
# 963    643230         Brault  -0.819980
# 964    643297            Ege   0.114234
# 965    643327         Godley  -2.187587
# 966    643338          Green  -1.352507
# 967    643354           Hart  -0.106305
# 968    643393        Kemp, T  -9.136876
# 969    643603          White  -9.482369
# 970    645848     Alvarez, D   1.462301
# 971    649557        Diaz, A  16.695314
# 972    656546        Hoffman  -2.036748
# 973    656941      Schwarber  -0.779726
# 974    660162        Moncada  -2.722085
# 975    666560           Park -12.022503
#
# [976 rows x 3 columns]

# %%
Player_Value17 = RE_17.groupby(['batterId'])['Run_Value'].sum().reset_index().rename(columns = {"Run_Value": 'RV17'})
Player_Value17
# Out:
#      batterId       RV17
# 0      112526  -6.053060
# 1      134181  27.205050
# 2      136860 -16.883042
# 3      150029  -7.246145
# 4      276520  -3.530974
# 5      282332  -0.292495
# 6      285079 -11.955467
# 7      400085   1.083044
# 8      400121 -16.021087
# 9      400284  -1.799883
# 10     405395 -13.892055
# 11     407793 -10.681085
# 12     407812   2.757927
# 13     407822   0.250916
# 14     408045  32.012389
# 15     408234  -4.336300
# 16     408236  -7.670641
# 17     408252  -5.977811
# 18     408314   1.076069
# 19     425509  -5.443013
# 20     425772 -16.127175
# 21     425783  22.048473
# 22     425784  -2.159875
# 23     425794  -0.042135
# 24     425844  -7.223913
# 25     425877  -2.878628
# 26     429664  26.869401
# 27     429665  21.707405
# 28     429666 -19.928385
# 29     429711  -1.771872
# ..        ...        ...
# 927    643414  -0.164138
# 928    643565  -0.688496
# 929    643603   2.336055
# 930    645277   2.934384
# 931    645302   0.613985
# 932    646240   1.741508
# 933    649557 -12.989348
# 934    650490  -2.698076
# 935    656185  -1.353194
# 936    656305   4.324205
# 937    656427  -1.427316
# 938    656546  -8.617175
# 939    656555  23.975547
# 940    656669  -2.290364
# 941    656756  -1.040102
# 942    656794  -7.766785
# 943    656941   1.261717
# 944    657077  -3.349964
# 945    657145  -1.410600
# 946    657524  -0.374947
# 947    657557   8.888592
# 948    658792  -1.070116
# 949    659275  -6.314271
# 950    660162   3.754225
# 951    664023   1.096874
# 952    664056  -1.443276
# 953    664057  -8.073984
# 954    664641  -2.145176
# 955    666561  -3.510460
# 956    669720  -3.328914
#
# [957 rows x 2 columns]

# %%
Players = pd.merge(Player_Value16,Player_Value17, on = ['batterId'])
Players
# Out:
#      batterId     batterName       RV16       RV17
# 0      112526          Colon -15.380841  -6.053060
# 1      134181         Beltre  29.745115  27.205050
# 2      136860        Beltran  21.279393 -16.883042
# 3      150029          Werth   6.368448  -7.246145
# 4      282332       Sabathia  -0.944580  -0.292495
# 5      285079         Dickey  -0.291686 -11.955467
# 6      400085      Suzuki, I  -2.577561   1.083044
# 7      400121    Martinez, V   7.335464 -16.021087
# 8      400284          Utley   6.689794  -1.799883
# 9      405395         Pujols  15.581010 -13.892055
# 10     407793         Lackey -14.016121 -10.681085
# 11     407812       Holliday  11.609729   2.757927
# 12     407822  De La Rosa, J  -2.222822   0.250916
# 13     408045          Mauer   3.738712  32.012389
# 14     408234        Cabrera  37.520249  -4.336300
# 15     408234     Cabrera, M   0.085720  -4.336300
# 16     408236    Gonzalez, A  18.186314  -7.670641
# 17     408252       Phillips  -2.507057  -5.977811
# 18     408314       Reyes, J   4.807395   1.076069
# 19     425509     Peralta, J  -9.323527  -5.443013
# 20     425772         Mathis  -4.741811 -16.127175
# 21     425783           Choo   7.278887  22.048473
# 22     425784      Rivera, R  -6.810194  -2.159875
# 23     425794     Wainwright   4.398501  -0.042135
# 24     425844        Greinke  -6.842665  -7.223913
# 25     425877         Molina   2.929933  -2.878628
# 26     429664           Cano  28.497452  26.869401
# 27     429665    Encarnacion  36.225266  21.707405
# 28     429666          Hardy  -2.402668 -19.928385
# 29     429711   Gutierrez, F   3.073617  -1.771872
# ..        ...            ...        ...        ...
# 668    623182       Kivlehan  -0.580243   2.975372
# 669    623395      Ellington  -0.162373  -0.164138
# 670    624424       Conforto  -3.607318  35.827160
# 671    624428     Frazier, A  -0.383171   7.720480
# 672    624577           Puig   1.871468   5.385486
# 673    624585          Soler   0.719051 -11.179351
# 674    628317          Maeda -10.436606  -6.261101
# 675    628338        Heredia   1.467905 -18.875920
# 676    628452    Iglesias, R  -2.118223   0.638454
# 677    628711          Urias  -2.416465  -0.921950
# 678    630111          Tomas   8.029901   3.337393
# 679    640455         Manaea  -0.508653  -0.358366
# 680    640461         Pinder  -3.441069  -3.679461
# 681    640463        Shipley  -3.829643  -2.111292
# 682    641313   Anderson, Ti -11.022494 -29.855271
# 683    641319         Asuaje  -0.135144  -5.254972
# 684    641771           Kuhl  -4.940016  -6.495571
# 685    641820        Mancini   3.565277  18.417190
# 686    642003           Reed  -2.960509  -0.272176
# 687    642162        Valaika  -1.942206   8.963447
# 688    642239      Zastryzny  -1.046863  -0.301836
# 689    643217     Benintendi   7.762445  14.129862
# 690    643230         Brault  -0.819980  -0.197529
# 691    643327         Godley  -2.187587  -8.961008
# 692    643393        Kemp, T  -9.136876  -1.489757
# 693    643603          White  -9.482369   2.336055
# 694    649557        Diaz, A  16.695314 -12.989348
# 695    656546        Hoffman  -2.036748  -8.617175
# 696    656941      Schwarber  -0.779726   1.261717
# 697    660162        Moncada  -2.722085   3.754225
#
# [698 rows x 4 columns]

# %% [markdown]
# Using a scatter diagram is a good way to compare consistency between seasons. If performance from season to season were perfectly correlated, we would observe every dot, which indicates an individual player, ranged along a 45 degree line running for the bottom left to the top right of the chart. In reality, the data is far more dispersed.

# %%
sns.regplot(x="RV16", y="RV17", color= 'black', fit_reg= True ,scatter_kws={'s':5},data= Players)

# %% [markdown]
# As before, we calculate the correlation coefficient. There clearly is a positive correlation, but it is not nearly as strong as it is for the event values.

# %%
np.corrcoef(Players.RV16, Players.RV17)
# Out:
# array([[1.        , 0.45381487],
#        [0.45381487, 1.        ]])

# %% [markdown]
# ## Self Test
#
# One explanation for the low correlation may be that in one or both years some players have relatively few at-bats, and hence the performance measure is noisy. Identify the number of appearances by players in the 2016 and 2017 data, and then derive the correlation coefficient. What do you conclude from this?

# %%
#Your Code Here

# %% [markdown]
# ## 3. Comparing Team Run Values
#
# The next step is to compare the runs values for each team across the season, to see how closely these correlate with winning records of the teams.

# %%
# Since each event is identified as occurring at the top of the inning (away team) or bottom of the inning (home team),
#we can use this variable to associate each event with the offensive record of the batter's team.

RE_17['team']= np.where(RE_17['half']=='top',RE_17['away_team'],RE_17['home_team'])
RE_17
# Out:
#        home_team away_team    half                          gameId  \
# 0            tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 1            tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 2            tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 3            tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 4            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 5            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 6            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 7            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 8            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 9            tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 10           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 11           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 12           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 13           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 14           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 15           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 16           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 17           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 18           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 19           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 20           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 21           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 22           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 23           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 24           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 25           tba       nya     top  gid_2017_04_02_nyamlb_tbamlb_1
# 26           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 27           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 28           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# 29           tba       nya  bottom  gid_2017_04_02_nyamlb_tbamlb_1
# ...          ...       ...     ...                             ...
# 184721       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184722       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184723       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184724       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184725       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184726       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184727       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184728       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184729       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184730       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184731       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184732       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184733       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184734       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184735       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184736       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184737       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184738       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184739       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184740       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184741       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184742       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184743       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184744       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184745       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184746       chn       cin     top  gid_2017_10_01_cinmlb_chnmlb_1
# 184747       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184748       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184749       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
# 184750       chn       cin  bottom  gid_2017_10_01_cinmlb_chnmlb_1
#
#           batterName  batterId       event   start1B   start2B   start3B  ...  \
# 0            Gardner    458731      Flyout       NaN       NaN       NaN  ...
# 1         Sanchez, G    596142   Groundout       NaN       NaN       NaN  ...
# 2               Bird    595885        Walk       NaN       NaN       NaN  ...
# 3           Holliday    407812   Groundout  595885.0       NaN       NaN  ...
# 4       Dickerson, C    572816      Single       NaN       NaN       NaN  ...
# 5          Kiermaier    595281      Double  572816.0       NaN       NaN  ...
# 6           Longoria    446334     Sac Fly       NaN  595281.0  572816.0  ...
# 7          Miller, B    543543      Single       NaN  595281.0       NaN  ...
# 8          Souza Jr.    519306        Walk  543543.0       NaN  595281.0  ...
# 9           Morrison    489149      Single  519306.0  543543.0  595281.0  ...
# 10           Beckham    542921     Lineout  489149.0  519306.0       NaN  ...
# 11          Smith, M    605480   Strikeout  489149.0  519306.0       NaN  ...
# 12          Ellsbury    453056      Flyout       NaN       NaN       NaN  ...
# 13         Castro, S    516770      Single       NaN       NaN       NaN  ...
# 14           Headley    452104      Single  516770.0       NaN       NaN  ...
# 15             Judge    592450      Double  452104.0  516770.0       NaN  ...
# 16          Torreyes    591720   Groundout       NaN  592450.0  452104.0  ...
# 17           Gardner    458731   Groundout       NaN       NaN  592450.0  ...
# 18        Norris, De    519083   Groundout       NaN       NaN       NaN  ...
# 19      Dickerson, C    572816   Strikeout       NaN       NaN       NaN  ...
# 20         Kiermaier    595281        Walk       NaN       NaN       NaN  ...
# 21          Longoria    446334    Home Run  595281.0       NaN       NaN  ...
# 22         Miller, B    543543      Flyout       NaN       NaN       NaN  ...
# 23        Sanchez, G    596142   Groundout       NaN       NaN       NaN  ...
# 24              Bird    595885      Flyout       NaN       NaN       NaN  ...
# 25          Holliday    407812   Strikeout       NaN       NaN       NaN  ...
# 26         Souza Jr.    519306   Strikeout       NaN       NaN       NaN  ...
# 27          Morrison    489149    Home Run       NaN       NaN       NaN  ...
# 28           Beckham    542921      Double       NaN       NaN       NaN  ...
# 29          Smith, M    605480      Single       NaN  542921.0       NaN  ...
# ...              ...       ...         ...       ...       ...       ...  ...
# 184721        Duvall    594807      Double       NaN       NaN       NaN  ...
# 184722        Suarez    553993      Single       NaN  594807.0       NaN  ...
# 184723       Gennett    571697      Single  553993.0       NaN  594807.0  ...
# 184724         Ervin    640447     Lineout  571697.0  553993.0       NaN  ...
# 184725       Wallach    595453   Strikeout  571697.0  553993.0       NaN  ...
# 184726      Davis, T    543089      Flyout       NaN       NaN       NaN  ...
# 184727    Almora Jr.    546991   Groundout       NaN       NaN       NaN  ...
# 184728       Freeman    502273   Groundout       NaN       NaN       NaN  ...
# 184729      Kivlehan    623182   Groundout       NaN       NaN       NaN  ...
# 184730      Hamilton    571740     Lineout       NaN       NaN       NaN  ...
# 184731        Vincej    572227   Strikeout       NaN       NaN       NaN  ...
# 184732       Zobrist    450314   Strikeout       NaN       NaN       NaN  ...
# 184733      Pena, Fe    570240   Strikeout       NaN       NaN       NaN  ...
# 184734     Schwarber    656941   Groundout       NaN       NaN       NaN  ...
# 184735         Votto    458015      Double       NaN       NaN       NaN  ...
# 184736        Duvall    594807   Strikeout       NaN  458015.0       NaN  ...
# 184737        Suarez    553993      Flyout       NaN  458015.0       NaN  ...
# 184738       Gennett    571697   Strikeout       NaN  458015.0       NaN  ...
# 184739      Caratini    605170   Strikeout       NaN       NaN       NaN  ...
# 184740     La Stella    600303   Strikeout       NaN       NaN       NaN  ...
# 184741       Happ, I    664023   Strikeout       NaN       NaN       NaN  ...
# 184742         Ervin    640447      Flyout       NaN       NaN       NaN  ...
# 184743       Wallach    595453   Strikeout       NaN       NaN       NaN  ...
# 184744        Winker    608385      Single       NaN       NaN       NaN  ...
# 184745      Hamilton    571740        Walk  608385.0       NaN       NaN  ...
# 184746        Vincej    572227  Runner Out  571740.0  608385.0       NaN  ...
# 184747      Davis, T    543089   Groundout       NaN       NaN       NaN  ...
# 184748    Almora Jr.    546991    Home Run       NaN       NaN       NaN  ...
# 184749       Freeman    502273   Groundout       NaN       NaN       NaN  ...
# 184750       Zobrist    450314   Groundout       NaN       NaN       NaN  ...
#
#         Start3  Start_State  End1  End2  End3  End_State  Start_RE    End_RE  \
# 0            0        000 0     0     0     0      000 1  0.516375  0.272176
# 1            0        000 1     0     0     0      000 2  0.272176  0.108038
# 2            0        000 2     1     0     0      100 2  0.108038  0.225365
# 3            0        100 2     0     0     0      000 3  0.225365  0.000000
# 4            0        000 0     1     0     0      100 0  0.516375  0.912921
# 5            0        100 0     0     1     1      011 0  0.912921  2.051376
# 6            1        011 0     0     1     0      010 1  2.051376  0.711650
# 7            0        010 1     1     0     1      101 1  0.711650  1.215306
# 8            1        101 1     1     1     1      111 1  1.215306  1.635608
# 9            1        111 1     1     1     0      110 1  1.635608  0.947424
# 10           0        110 1     1     1     0      110 2  0.947424  0.449782
# 11           0        110 2     0     0     0      000 3  0.449782  0.000000
# 12           0        000 0     0     0     0      000 1  0.516375  0.272176
# 13           0        000 1     1     0     0      100 1  0.272176  0.524904
# 14           0        100 1     1     1     0      110 1  0.524904  0.947424
# 15           0        110 1     0     1     1      011 1  0.947424  1.517131
# 16           1        011 1     0     0     1      001 2  1.517131  0.381186
# 17           1        001 2     0     0     0      000 3  0.381186  0.000000
# 18           0        000 0     0     0     0      000 1  0.516375  0.272176
# 19           0        000 1     0     0     0      000 2  0.272176  0.108038
# 20           0        000 2     1     0     0      100 2  0.108038  0.225365
# 21           0        100 2     0     0     0      000 2  0.225365  0.108038
# 22           0        000 2     0     0     0      000 3  0.108038  0.000000
# 23           0        000 0     0     0     0      000 1  0.516375  0.272176
# 24           0        000 1     0     0     0      000 2  0.272176  0.108038
# 25           0        000 2     0     0     0      000 3  0.108038  0.000000
# 26           0        000 0     0     0     0      000 1  0.516375  0.272176
# 27           0        000 1     0     0     0      000 1  0.272176  0.272176
# 28           0        000 1     0     1     0      010 1  0.272176  0.711650
# 29           0        010 1     0     1     0      010 1  0.711650  0.711650
# ...        ...          ...   ...   ...   ...        ...       ...       ...
# 184721       0        000 1     0     1     0      010 1  0.272176  0.711650
# 184722       0        010 1     1     0     1      101 1  0.711650  1.215306
# 184723       1        101 1     1     1     0      110 1  1.215306  0.947424
# 184724       0        110 1     1     1     0      110 2  0.947424  0.449782
# 184725       0        110 2     0     0     0      000 3  0.449782  0.000000
# 184726       0        000 0     0     0     0      000 1  0.516375  0.272176
# 184727       0        000 1     0     0     0      000 2  0.272176  0.108038
# 184728       0        000 2     0     0     0      000 3  0.108038  0.000000
# 184729       0        000 0     0     0     0      000 1  0.516375  0.272176
# 184730       0        000 1     0     0     0      000 2  0.272176  0.108038
# 184731       0        000 2     0     0     0      000 3  0.108038  0.000000
# 184732       0        000 0     0     0     0      000 1  0.516375  0.272176
# 184733       0        000 1     0     0     0      000 2  0.272176  0.108038
# 184734       0        000 2     0     0     0      000 3  0.108038  0.000000
# 184735       0        000 0     0     1     0      010 0  0.516375  1.154829
# 184736       0        010 0     0     1     0      010 1  1.154829  0.711650
# 184737       0        010 1     0     1     0      010 2  0.711650  0.336702
# 184738       0        010 2     0     0     0      000 3  0.336702  0.000000
# 184739       0        000 0     0     0     0      000 1  0.516375  0.272176
# 184740       0        000 1     0     0     0      000 2  0.272176  0.108038
# 184741       0        000 2     0     0     0      000 3  0.108038  0.000000
# 184742       0        000 0     0     0     0      000 1  0.516375  0.272176
# 184743       0        000 1     0     0     0      000 2  0.272176  0.108038
# 184744       0        000 2     1     0     0      100 2  0.108038  0.225365
# 184745       0        100 2     1     1     0      110 2  0.225365  0.449782
# 184746       0        110 2     0     0     0      000 3  0.449782  0.000000
# 184747       0        000 0     0     0     0      000 1  0.516375  0.272176
# 184748       0        000 1     0     0     0      000 1  0.272176  0.272176
# 184749       0        000 1     0     0     0      000 2  0.272176  0.108038
# 184750       0        000 2     0     0     0      000 3  0.108038  0.000000
#
#         Run_Value team
# 0       -0.244199  nya
# 1       -0.164138  nya
# 2        0.117327  nya
# 3       -0.225365  nya
# 4        0.396546  tba
# 5        1.138455  tba
# 6       -0.339727  tba
# 7        0.503657  tba
# 8        0.420302  tba
# 9        1.311816  tba
# 10      -0.497642  tba
# 11      -0.449782  tba
# 12      -0.244199  nya
# 13       0.252728  nya
# 14       0.422520  nya
# 15       1.569707  nya
# 16      -0.135945  nya
# 17      -0.381186  nya
# 18      -0.244199  tba
# 19      -0.164138  tba
# 20       0.117327  tba
# 21       1.882673  tba
# 22      -0.108038  tba
# 23      -0.244199  nya
# 24      -0.164138  nya
# 25      -0.108038  nya
# 26      -0.244199  tba
# 27       1.000000  tba
# 28       0.439473  tba
# 29       1.000000  tba
# ...           ...  ...
# 184721   0.439473  cin
# 184722   0.503657  cin
# 184723   0.732118  cin
# 184724  -0.497642  cin
# 184725  -0.449782  cin
# 184726  -0.244199  chn
# 184727  -0.164138  chn
# 184728  -0.108038  chn
# 184729  -0.244199  cin
# 184730  -0.164138  cin
# 184731  -0.108038  cin
# 184732  -0.244199  chn
# 184733  -0.164138  chn
# 184734  -0.108038  chn
# 184735   0.638454  cin
# 184736  -0.443179  cin
# 184737  -0.374947  cin
# 184738  -0.336702  cin
# 184739  -0.244199  chn
# 184740  -0.164138  chn
# 184741  -0.108038  chn
# 184742  -0.244199  cin
# 184743  -0.164138  cin
# 184744   0.117327  cin
# 184745   0.224418  cin
# 184746  -0.449782  cin
# 184747  -0.244199  chn
# 184748   1.000000  chn
# 184749  -0.164138  chn
# 184750  -0.108038  chn
#
# [184751 rows x 32 columns]

# %%
RE_16['team']= np.where(RE_16['half']=='top',RE_16['away_team'],RE_16['home_team'])
RE_16
# Out:
#        home_team away_team    half                          gameId  \
# 0            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 1            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 2            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 3            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 4            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 5            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 6            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 7            pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 8            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 9            pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 10           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 11           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 12           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 13           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 14           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 15           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 16           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 17           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 18           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 19           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 20           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 21           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 22           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 23           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 24           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 25           pit       sln  bottom  gid_2016_04_03_slnmlb_pitmlb_1
# 26           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 27           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 28           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# 29           pit       sln     top  gid_2016_04_03_slnmlb_pitmlb_1
# ...          ...       ...     ...                             ...
# 184122       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184123       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184124       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184125       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184126       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184127       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184128       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184129       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184130       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184131       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184132       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184133       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184134       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184135       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184136       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184137       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184138       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184139       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184140       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184141       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184142       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184143       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184144       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184145       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184146       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184147       sln       pit  bottom  gid_2016_10_02_pitmlb_slnmlb_1
# 184148       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184149       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184150       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
# 184151       sln       pit     top  gid_2016_10_02_pitmlb_slnmlb_1
#
#           batterName  batterId             event   start1B   start2B  \
# 0       Carpenter, M    572761         Groundout       NaN       NaN
# 1               Pham    502054         Groundout       NaN       NaN
# 2           Holliday    407812         Strikeout       NaN       NaN
# 3               Jaso    444379         Groundout       NaN       NaN
# 4          McCutchen    457705      Hit By Pitch       NaN       NaN
# 5             Freese    501896            Single  457705.0       NaN
# 6           Marte, S    516782           Lineout  501896.0       NaN
# 7           Cervelli    465041           Pop Out  501896.0       NaN
# 8            Grichuk    545341         Strikeout       NaN       NaN
# 9           Piscotty    572039         Strikeout       NaN       NaN
# 10            Molina    425877         Strikeout       NaN       NaN
# 11        Polanco, G    570256            Double       NaN       NaN
# 12          Harrison    543281         Groundout       NaN  570256.0
# 13            Mercer    474568              Walk       NaN       NaN
# 14           Liriano    434538            Single  474568.0       NaN
# 15              Jaso    444379            Single  434538.0  474568.0
# 16         McCutchen    457705            Flyout  444379.0  434538.0
# 17            Freese    501896         Groundout  444379.0  434538.0
# 18              Wong    543939         Strikeout       NaN       NaN
# 19            Gyorko    576397              Walk       NaN       NaN
# 20        Wainwright    425794       Field Error  576397.0       NaN
# 21      Carpenter, M    572761  Grounded Into DP  425794.0       NaN
# 22          Marte, S    516782           Lineout       NaN       NaN
# 23          Cervelli    465041              Walk       NaN       NaN
# 24        Polanco, G    570256            Flyout  465041.0       NaN
# 25          Harrison    543281         Strikeout  465041.0       NaN
# 26             Adams    571431         Strikeout       NaN       NaN
# 27          Holliday    407812            Single       NaN       NaN
# 28           Grichuk    545341            Single  407812.0       NaN
# 29          Piscotty    572039         Strikeout  545341.0  407812.0
# ...              ...       ...               ...       ...       ...
# 184122       Grichuk    545341         Strikeout  576397.0       NaN
# 184123  Martinez, Jo    500874            Single  576397.0       NaN
# 184124  Carpenter, M    572761          Home Run  500874.0  576397.0
# 184125       Diaz, A    649557         Strikeout       NaN       NaN
# 184126    Frazier, A    624428            Single       NaN       NaN
# 184127          Jaso    444379          Home Run  624428.0       NaN
# 184128    Polanco, G    570256         Strikeout       NaN       NaN
# 184129     McCutchen    457705            Flyout       NaN       NaN
# 184130          Kang    628356         Strikeout       NaN       NaN
# 184131        Molina    425877            Double       NaN       NaN
# 184132      Piscotty    572039            Single       NaN  425877.0
# 184133    Peralta, J    425509            Single  572039.0       NaN
# 184134          Moss    461235            Single  425509.0  572039.0
# 184135        Gyorko    576397       Field Error  461235.0  425509.0
# 184136       Grichuk    545341            Double  576397.0  461235.0
# 184137         Adams    571431           Sac Fly       NaN  545341.0
# 184138  Carpenter, M    572761           Sac Fly       NaN       NaN
# 184139       Diaz, A    649557           Pop Out       NaN       NaN
# 184140         Joyce    459964         Groundout       NaN       NaN
# 184141        Hanson    593700            Flyout       NaN       NaN
# 184142         Fryer    518700            Single       NaN       NaN
# 184143      Florimon    465753         Groundout  518700.0       NaN
# 184144        Molina    425877         Groundout       NaN       NaN
# 184145      Piscotty    572039         Strikeout       NaN       NaN
# 184146     Garcia, G    594824            Single       NaN       NaN
# 184147          Moss    461235         Strikeout  594824.0       NaN
# 184148     Rogers, J    595386         Groundout       NaN       NaN
# 184149          Jaso    444379              Walk       NaN       NaN
# 184150    Polanco, G    570256         Strikeout  444379.0       NaN
# 184151     McCutchen    457705         Groundout  444379.0       NaN
#
#          start3B  ...  Start3  Start_State  End1  End2  End3  End_State  \
# 0            NaN  ...       0        000 0     0     0     0      000 1
# 1            NaN  ...       0        000 1     0     0     0      000 2
# 2            NaN  ...       0        000 2     0     0     0      000 3
# 3            NaN  ...       0        000 0     0     0     0      000 1
# 4            NaN  ...       0        000 1     1     0     0      100 1
# 5            NaN  ...       0        100 1     1     0     1      101 1
# 6       457705.0  ...       1        101 1     1     0     1      101 2
# 7       457705.0  ...       1        101 2     0     0     0      000 3
# 8            NaN  ...       0        000 0     0     0     0      000 1
# 9            NaN  ...       0        000 1     0     0     0      000 2
# 10           NaN  ...       0        000 2     0     0     0      000 3
# 11           NaN  ...       0        000 0     0     1     0      010 0
# 12           NaN  ...       0        010 0     0     0     1      001 1
# 13      570256.0  ...       1        001 1     1     0     1      101 1
# 14      570256.0  ...       1        101 1     1     1     0      110 1
# 15           NaN  ...       0        110 1     1     1     0      110 1
# 16           NaN  ...       0        110 1     1     1     0      110 2
# 17           NaN  ...       0        110 2     0     0     0      000 3
# 18           NaN  ...       0        000 0     0     0     0      000 1
# 19           NaN  ...       0        000 1     1     0     0      100 1
# 20           NaN  ...       0        100 1     1     0     1      101 1
# 21      576397.0  ...       1        101 1     0     0     0      000 3
# 22           NaN  ...       0        000 0     0     0     0      000 1
# 23           NaN  ...       0        000 1     1     0     0      100 1
# 24           NaN  ...       0        100 1     1     0     0      100 2
# 25           NaN  ...       0        100 2     0     0     0      000 3
# 26           NaN  ...       0        000 0     0     0     0      000 1
# 27           NaN  ...       0        000 1     1     0     0      100 1
# 28           NaN  ...       0        100 1     1     1     0      110 1
# 29           NaN  ...       0        110 1     1     1     0      110 2
# ...          ...  ...     ...          ...   ...   ...   ...        ...
# 184122       NaN  ...       0        100 1     1     0     0      100 2
# 184123       NaN  ...       0        100 2     1     1     0      110 2
# 184124       NaN  ...       0        110 2     0     0     0      000 2
# 184125       NaN  ...       0        000 2     0     0     0      000 3
# 184126       NaN  ...       0        000 0     1     0     0      100 0
# 184127       NaN  ...       0        100 0     0     0     0      000 0
# 184128       NaN  ...       0        000 0     0     0     0      000 1
# 184129       NaN  ...       0        000 1     0     0     0      000 2
# 184130       NaN  ...       0        000 2     0     0     0      000 3
# 184131       NaN  ...       0        000 0     0     1     0      010 0
# 184132       NaN  ...       0        010 0     1     0     0      100 0
# 184133       NaN  ...       0        100 0     1     1     0      110 0
# 184134       NaN  ...       0        110 0     1     1     1      111 0
# 184135  572039.0  ...       1        111 0     1     1     1      111 0
# 184136  425509.0  ...       1        111 0     0     1     1      011 0
# 184137  576397.0  ...       1        011 0     0     0     1      001 1
# 184138  545341.0  ...       1        001 1     0     0     0      000 2
# 184139       NaN  ...       0        000 2     0     0     0      000 3
# 184140       NaN  ...       0        000 0     0     0     0      000 1
# 184141       NaN  ...       0        000 1     0     0     0      000 2
# 184142       NaN  ...       0        000 2     1     0     0      100 2
# 184143       NaN  ...       0        100 2     0     0     0      000 3
# 184144       NaN  ...       0        000 0     0     0     0      000 1
# 184145       NaN  ...       0        000 1     0     0     0      000 2
# 184146       NaN  ...       0        000 2     1     0     0      100 2
# 184147       NaN  ...       0        100 2     0     0     0      000 3
# 184148       NaN  ...       0        000 0     0     0     0      000 1
# 184149       NaN  ...       0        000 1     1     0     0      100 1
# 184150       NaN  ...       0        100 1     1     0     0      100 2
# 184151       NaN  ...       0        100 2     0     0     0      000 3
#
#         Start_RE    End_RE  Run_Value team
# 0       0.498377  0.268678  -0.229699  sln
# 1       0.268678  0.106305  -0.162373  sln
# 2       0.106305  0.000000  -0.106305  sln
# 3       0.498377  0.268678  -0.229699  pit
# 4       0.268678  0.512225   0.243547  pit
# 5       0.512225  1.196777   0.684552  pit
# 6       1.196777  0.480175  -0.716603  pit
# 7       0.480175  0.000000  -0.480175  pit
# 8       0.498377  0.268678  -0.229699  sln
# 9       0.268678  0.106305  -0.162373  sln
# 10      0.106305  0.000000  -0.106305  sln
# 11      0.498377  1.132468   0.634090  pit
# 12      1.132468  0.948684  -0.183783  pit
# 13      0.948684  1.196777   0.248093  pit
# 14      1.196777  0.922572   0.725795  pit
# 15      0.922572  0.922572   1.000000  pit
# 16      0.922572  0.414466  -0.508107  pit
# 17      0.414466  0.000000  -0.414466  pit
# 18      0.498377  0.268678  -0.229699  sln
# 19      0.268678  0.512225   0.243547  sln
# 20      0.512225  1.196777   0.684552  sln
# 21      1.196777  0.000000  -1.196777  sln
# 22      0.498377  0.268678  -0.229699  pit
# 23      0.268678  0.512225   0.243547  pit
# 24      0.512225  0.220539  -0.291686  pit
# 25      0.220539  0.000000  -0.220539  pit
# 26      0.498377  0.268678  -0.229699  sln
# 27      0.268678  0.512225   0.243547  sln
# 28      0.512225  0.922572   0.410347  sln
# 29      0.922572  0.414466  -0.508107  sln
# ...          ...       ...        ...  ...
# 184122  0.512225  0.220539  -0.291686  sln
# 184123  0.220539  0.414466   0.193926  sln
# 184124  0.414466  0.106305   2.691840  sln
# 184125  0.106305  0.000000  -0.106305  sln
# 184126  0.498377  0.858504   0.360127  pit
# 184127  0.858504  0.498377   1.639873  pit
# 184128  0.498377  0.268678  -0.229699  pit
# 184129  0.268678  0.106305  -0.162373  pit
# 184130  0.106305  0.000000  -0.106305  pit
# 184131  0.498377  1.132468   0.634090  sln
# 184132  1.132468  0.858504   0.726037  sln
# 184133  0.858504  1.447597   0.589092  sln
# 184134  1.447597  2.112409   0.664812  sln
# 184135  2.112409  2.112409   1.000000  sln
# 184136  2.112409  1.916190   1.803782  sln
# 184137  1.916190  0.948684   0.032494  sln
# 184138  0.948684  0.106305   0.157621  sln
# 184139  0.106305  0.000000  -0.106305  sln
# 184140  0.498377  0.268678  -0.229699  pit
# 184141  0.268678  0.106305  -0.162373  pit
# 184142  0.106305  0.220539   0.114234  pit
# 184143  0.220539  0.000000  -0.220539  pit
# 184144  0.498377  0.268678  -0.229699  sln
# 184145  0.268678  0.106305  -0.162373  sln
# 184146  0.106305  0.220539   0.114234  sln
# 184147  0.220539  0.000000  -0.220539  sln
# 184148  0.498377  0.268678  -0.229699  pit
# 184149  0.268678  0.512225   0.243547  pit
# 184150  0.512225  0.220539  -0.291686  pit
# 184151  0.220539  0.000000  -0.220539  pit
#
# [184152 rows x 32 columns]

# %%
# We use .groupby to calculate the sum of runs values for each team in each season and then merge to two frames to make 
# comparisons

REteam_17= RE_17.groupby(['team'])['Run_Value'].sum().reset_index().rename(columns= {"Run_Value": 'RV17'})
REteam_16= RE_16.groupby(['team'])['Run_Value'].sum().reset_index().rename(columns= {"Run_Value": 'RV16'})
REteam1617 = pd.merge(REteam_16,REteam_17, on=['team'])
REteam1617
# Out:
#    team        RV16        RV17
# 0   ana   -3.184209  -47.579782
# 1   ari   15.870968   62.616716
# 2   atl  -84.633901  -28.259905
# 3   bal   29.297940  -23.678031
# 4   bos  160.812546    9.445347
# 5   cha  -41.643638  -47.416033
# 6   chn   85.327151   71.002092
# 7   cin  -17.643638    5.420218
# 8   cle   48.815791   73.780465
# 9   col  122.825528   78.616716
# 10  det   30.327151  -14.997908
# 11  hou  -19.624164  152.296840
# 12  kca  -60.666358  -54.514283
# 13  lan   -2.161489   17.747715
# 14  mia  -61.672849   25.871093
# 15  mil  -48.679340  -11.383284
# 16  min  -15.633901   69.583967
# 17  nya  -40.203683  107.485717
# 18  nyn  -54.164735  -15.030657
# 19  oak  -79.161489  -19.481533
# 20  phi -115.656621  -68.259905
# 21  pit    5.343379  -92.128907
# 22  sdn  -49.650129 -143.030657
# 23  sea   29.353117   -3.448783
# 24  sfn  -17.142015 -126.489153
# 25  sln   48.336888    6.838344
# 26  tba  -47.167980  -57.161656
# 27  tex   41.812546   48.002092
# 28  tor   25.851494  -81.456403
# 29  was   32.825528   64.616716

# %%
sns.regplot(x="RV16", y="RV17", color= 'black', fit_reg= True ,scatter_kws={'s':5},data= REteam1617)

# %% [markdown]
# We find a modest correlation in Runs Values between the two seasons.

# %%
np.corrcoef(REteam1617.RV16, REteam1617.RV17)
# Out:
# array([[1.        , 0.35170819],
#        [0.35170819, 1.        ]])

# %% [markdown]
# ## Self Test
#
# Compare the correlation in Runs Values for the seasons 2015 and 2017. Do you find the same pattern? Why or why not?

# %%
#Your Code Here

# %% [markdown]
# ## 4. Comparing Run Values, Win Percentage, and Salary Data
#
# Runs values can be considered both as a factor that explains winning - teams that achieve a higher Runs Value are performing better than expected, and hence are more likely to win - or as a predictor of winning in the future. To the extent that the market for players is efficient in an economic sense, player salaries will also reflect both current and future performance. So we can use our data to make these comparisons.
#
# We take the salary data for 2016 from the Lahman database. We download a file which includes the regular season win percentage for each team in 2016 and 2017 and the total paid out in salaries in 2016.

# %%
wpcsal1617 = pd.read_excel("../Data/wpcsal2016-17.xlsx")
wpcsal1617
# Out:
#    team   wpc2016   wpc2017    Sal2016 lahteamname
# 0   ari  0.425926  0.574074   87439063         ARI
# 1   atl  0.422360  0.444444   68498291         ATL
# 2   bal  0.549383  0.462963  161863456         BAL
# 3   bos  0.574074  0.574074  188545761         BOS
# 4   cha  0.481481  0.413580  112998667         CHA
# 5   chn  0.635802  0.567901  154067668         CHN
# 6   cin  0.419753  0.419753   88940059         CIN
# 7   cle  0.583851  0.629630   74311900         CLE
# 8   col  0.462963  0.537037  112645071         COL
# 9   det  0.534161  0.395062  194876481         DET
# 10  hou  0.518519  0.623457   94893700         HOU
# 11  kca  0.500000  0.493827  131487125         KCA
# 12  ana  0.456790  0.493827  137251333         LAA
# 13  lan  0.561728  0.641975  221288380         LAN
# 14  mia  0.490683  0.475309   77314202         MIA
# 15  mil  0.450617  0.530864   68775237         MIL
# 16  min  0.364198  0.524691  102583200         MIN
# 17  nya  0.518519  0.561728  222997792         NYA
# 18  nyn  0.537037  0.432099  133889129         NYN
# 19  oak  0.425926  0.462963   86806234         OAK
# 20  phi  0.438272  0.407407   58980000         PHI
# 21  pit  0.481481  0.462963  103778833         PIT
# 22  sdn  0.419753  0.438272  101424814         SDN
# 23  sea  0.530864  0.481481  135683339         SEA
# 24  sfn  0.537037  0.395062  172253778         SFN
# 25  sln  0.530864  0.512346  143053500         SLN
# 26  tba  0.419753  0.493827   57097310         TBA
# 27  tex  0.586420  0.481481  176038723         TEX
# 28  tor  0.549383  0.469136  138701700         TOR
# 29  was  0.586420  0.598765  141652646         WAS

# %% [markdown]
# ## Self Test
#
# The win percentages for each can be derived directly from RE_16 and RE_17. To do this, .groupby to sum the runs scored by each team in each game and denote the winner as the team with more runs (1 if the winner, 0 otherwise) and then use .groupby to find the mean of wins - that is win percentage. Check that your answer matches the data for win percentage downloaded here.

# %%
# Here we merge the Runs Value df with the Win Percentage df

REteam1617 = pd.merge(REteam1617,wpcsal1617, on = ['team'])
REteam1617
# Out:
#    team        RV16        RV17   wpc2016   wpc2017    Sal2016 lahteamname
# 0   ana   -3.184209  -47.579782  0.456790  0.493827  137251333         LAA
# 1   ari   15.870968   62.616716  0.425926  0.574074   87439063         ARI
# 2   atl  -84.633901  -28.259905  0.422360  0.444444   68498291         ATL
# 3   bal   29.297940  -23.678031  0.549383  0.462963  161863456         BAL
# 4   bos  160.812546    9.445347  0.574074  0.574074  188545761         BOS
# 5   cha  -41.643638  -47.416033  0.481481  0.413580  112998667         CHA
# 6   chn   85.327151   71.002092  0.635802  0.567901  154067668         CHN
# 7   cin  -17.643638    5.420218  0.419753  0.419753   88940059         CIN
# 8   cle   48.815791   73.780465  0.583851  0.629630   74311900         CLE
# 9   col  122.825528   78.616716  0.462963  0.537037  112645071         COL
# 10  det   30.327151  -14.997908  0.534161  0.395062  194876481         DET
# 11  hou  -19.624164  152.296840  0.518519  0.623457   94893700         HOU
# 12  kca  -60.666358  -54.514283  0.500000  0.493827  131487125         KCA
# 13  lan   -2.161489   17.747715  0.561728  0.641975  221288380         LAN
# 14  mia  -61.672849   25.871093  0.490683  0.475309   77314202         MIA
# 15  mil  -48.679340  -11.383284  0.450617  0.530864   68775237         MIL
# 16  min  -15.633901   69.583967  0.364198  0.524691  102583200         MIN
# 17  nya  -40.203683  107.485717  0.518519  0.561728  222997792         NYA
# 18  nyn  -54.164735  -15.030657  0.537037  0.432099  133889129         NYN
# 19  oak  -79.161489  -19.481533  0.425926  0.462963   86806234         OAK
# 20  phi -115.656621  -68.259905  0.438272  0.407407   58980000         PHI
# 21  pit    5.343379  -92.128907  0.481481  0.462963  103778833         PIT
# 22  sdn  -49.650129 -143.030657  0.419753  0.438272  101424814         SDN
# 23  sea   29.353117   -3.448783  0.530864  0.481481  135683339         SEA
# 24  sfn  -17.142015 -126.489153  0.537037  0.395062  172253778         SFN
# 25  sln   48.336888    6.838344  0.530864  0.512346  143053500         SLN
# 26  tba  -47.167980  -57.161656  0.419753  0.493827   57097310         TBA
# 27  tex   41.812546   48.002092  0.586420  0.481481  176038723         TEX
# 28  tor   25.851494  -81.456403  0.549383  0.469136  138701700         TOR
# 29  was   32.825528   64.616716  0.586420  0.598765  141652646         WAS

# %% [markdown]
# ## Scatterplots
#
# The extent of correlation among the variables can be examined using scatterplots for each pair of variables

# %%
sns.regplot(x="RV16", y="wpc2016", color= 'black', fit_reg= True ,scatter_kws={'s':5},data= REteam1617)

# %%
sns.regplot(x="Sal2016", y="RV16" , color= 'black', fit_reg= True ,scatter_kws={'s':5},data= REteam1617)

# %%
sns.regplot(x="RV16", y="wpc2017", color= 'black', fit_reg= True ,scatter_kws={'s':5},data= REteam1617)

# %%
sns.regplot("Sal2016", y="RV17", color= 'black', fit_reg= True ,scatter_kws={'s':5},data= REteam1617)

# %% [markdown]
# ## Correlations
#
# We can generate a matrix of correlation coefficients using .corr()

# %%
REteam1617.corr()

# %% [markdown]
# ## Conclusions
#
# There is  high correlation between Runs Value and Win Percentage, especially in 2017. There is also a fairly high level of correlation between Runs Value in 2016 and Win Percentage in 2017 - it appears predictive to some extent. Runs Value is also fairly highly correlated with salary in a given year, but salaries in 2016 are not very closely correlated with Win Percentage in 2017.
#
# There are several possible explanations for this. Salaries are not as correlated with productivity (Runs Value) as one might expect in an open market, since rookies are not able to sell their services competitively and even 5 year veterans are constrained by arbitration (recall our analysis of salaries from Hakes and Sauer).
#
# It is also possible that salaries are more about rewarding past performance than future performance. Your opinion on this depends on how you think the markets work.
#
# It may also be the case that salary data is partial and incomplete.
#
# Runs Value is a very good measure of player productivity, which improves upon traditional statistics by taking account of context. It's no accident that statistical analysis in baseball is more advanced than in any other sport - the natural measurement of performance as the product of a series of discrete homogeneous events (at-bats) is unparalleled in sports. Baseball analysts have gone further and made adjustments to these statistics to generate a single, intuitive measure of productivity such as Wins Above Replacement (WAR). There is debate about how to make these adjustments and different versions of WAR exist. In many cases WAR is calculated on the basis of season average player stats adjusted for Run Expectancy - a method which then loses the context dependent values we have derived here. In any case, equipped with the capacity to produce Runs Value data, you should now be able to go on and produce your own version of WAR, if you so wish. An example of how to do this is given by Baumer, Jensen, and Matthews (2015) "openWAR: An open source system for evaluating overall player performance in major league baseball", which you can download online for free.
#
# Throughout this course we have focused on the relationship between productivity, performance and valuation. We have focused mainly on using data to *explain* the relationships, but we have also seen that it can have *predictive* value. This is the underlying story behind Moneyball, but is is also the story of sports analytics in general. In the next course we will focus in more detail on prediction and forecasting.
