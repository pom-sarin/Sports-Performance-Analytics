# %%
# This allows us to show the full screen width

from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
import pandas as pd
import numpy as np

# %%
BLmod = pd.read_excel("Assignment Data/Week 3/Bundesliga prediction model (Assignment).xlsx")
BLmod
# Out:
#            Date  gameno  day  month  year       HomeTeam            AwayTeam  \
# 0    16/08/2019       1   16      8  2019  Bayern Munich              Hertha
# 1    17/08/2019       2   17      8  2019       Dortmund            Augsburg
# 2    17/08/2019       3   17      8  2019      Wolfsburg             FC Koln
# 3    17/08/2019       4   17      8  2019  Werder Bremen  Fortuna Dusseldorf
# 4    17/08/2019       5   17      8  2019       Freiburg               Mainz
# ..          ...     ...  ...    ...   ...            ...                 ...
# 301  27/06/2020     302   27      6  2020       Dortmund          Hoffenheim
# 302  27/06/2020     303   27      6  2020     Leverkusen               Mainz
# 303  27/06/2020     304   27      6  2020  Ein Frankfurt           Paderborn
# 304  27/06/2020     305   27      6  2020       Augsburg          RB Leipzig
# 305  27/06/2020     306   27      6  2020       Freiburg          Schalke 04
#
# ...

# %%
BLmod['B365HPr']= 1/(BLmod['B365H'])/(1/(BLmod['B365H'])+ 1/(BLmod['B365D'])+ 1/(BLmod['B365A']))
BLmod['B365DPr']= 1/(BLmod['B365D'])/(1/(BLmod['B365H'])+ 1/(BLmod['B365D'])+ 1/(BLmod['B365A']))
BLmod['B365APr']= 1/(BLmod['B365A'])/(1/(BLmod['B365H'])+ 1/(BLmod['B365D'])+ 1/(BLmod['B365A']))
BLmod
# Out:
#            Date  gameno  day  month  year       HomeTeam            AwayTeam  \
# 0    16/08/2019       1   16      8  2019  Bayern Munich              Hertha
# 1    17/08/2019       2   17      8  2019       Dortmund            Augsburg
# 2    17/08/2019       3   17      8  2019      Wolfsburg             FC Koln
# 3    17/08/2019       4   17      8  2019  Werder Bremen  Fortuna Dusseldorf
# 4    17/08/2019       5   17      8  2019       Freiburg               Mainz
# ..          ...     ...  ...    ...   ...            ...                 ...
# 301  27/06/2020     302   27      6  2020       Dortmund          Hoffenheim
# 302  27/06/2020     303   27      6  2020     Leverkusen               Mainz
# 303  27/06/2020     304   27      6  2020  Ein Frankfurt           Paderborn
# 304  27/06/2020     305   27      6  2020       Augsburg          RB Leipzig
# 305  27/06/2020     306   27      6  2020       Freiburg          Schalke 04
#
# ...

# %%
BLmod['B365res']= np.where((BLmod['B365HPr']>BLmod['B365DPr']) & (BLmod['B365HPr']>BLmod['B365APr']),'H',\
                            np.where((BLmod['B365DPr']>BLmod['B365HPr']) & (BLmod['B365DPr']>BLmod['B365APr']),'D','A'))
BLmod
# Out:
#            Date  gameno  day  month  year       HomeTeam            AwayTeam  \
# 0    16/08/2019       1   16      8  2019  Bayern Munich              Hertha
# 1    17/08/2019       2   17      8  2019       Dortmund            Augsburg
# 2    17/08/2019       3   17      8  2019      Wolfsburg             FC Koln
# 3    17/08/2019       4   17      8  2019  Werder Bremen  Fortuna Dusseldorf
# 4    17/08/2019       5   17      8  2019       Freiburg               Mainz
# ..          ...     ...  ...    ...   ...            ...                 ...
# 301  27/06/2020     302   27      6  2020       Dortmund          Hoffenheim
# 302  27/06/2020     303   27      6  2020     Leverkusen               Mainz
# 303  27/06/2020     304   27      6  2020  Ein Frankfurt           Paderborn
# 304  27/06/2020     305   27      6  2020       Augsburg          RB Leipzig
# 305  27/06/2020     306   27      6  2020       Freiburg          Schalke 04
#
# ...

# %%
BLmod['winvalue'] = np.where(BLmod['FTR'] == 'H', 2 ,(np.where(BLmod['FTR'] == 'D', 1, 0)))
BLmod
# Out:
#            Date  gameno  day  month  year       HomeTeam            AwayTeam  \
# 0    16/08/2019       1   16      8  2019  Bayern Munich              Hertha
# 1    17/08/2019       2   17      8  2019       Dortmund            Augsburg
# 2    17/08/2019       3   17      8  2019      Wolfsburg             FC Koln
# 3    17/08/2019       4   17      8  2019  Werder Bremen  Fortuna Dusseldorf
# 4    17/08/2019       5   17      8  2019       Freiburg               Mainz
# ..          ...     ...  ...    ...   ...            ...                 ...
# 301  27/06/2020     302   27      6  2020       Dortmund          Hoffenheim
# 302  27/06/2020     303   27      6  2020     Leverkusen               Mainz
# 303  27/06/2020     304   27      6  2020  Ein Frankfurt           Paderborn
# 304  27/06/2020     305   27      6  2020       Augsburg          RB Leipzig
# 305  27/06/2020     306   27      6  2020       Freiburg          Schalke 04
#
# ...

# %%
pd.crosstab(BLmod['FTR'], BLmod['B365res'],dropna= True)
# Out:
# B365res   A   H
# FTR
# A        63  52
# D        18  50
# H        28  95

# %%
BLmod['lhTMratio'] = np.log(BLmod['Tmhome']/BLmod['Tmaway'])
BLmod
# Out:
#            Date  gameno  day  month  year       HomeTeam            AwayTeam  \
# 0    16/08/2019       1   16      8  2019  Bayern Munich              Hertha
# 1    17/08/2019       2   17      8  2019       Dortmund            Augsburg
# 2    17/08/2019       3   17      8  2019      Wolfsburg             FC Koln
# 3    17/08/2019       4   17      8  2019  Werder Bremen  Fortuna Dusseldorf
# 4    17/08/2019       5   17      8  2019       Freiburg               Mainz
# ..          ...     ...  ...    ...   ...            ...                 ...
# 301  27/06/2020     302   27      6  2020       Dortmund          Hoffenheim
# 302  27/06/2020     303   27      6  2020     Leverkusen               Mainz
# 303  27/06/2020     304   27      6  2020  Ein Frankfurt           Paderborn
# 304  27/06/2020     305   27      6  2020       Augsburg          RB Leipzig
# 305  27/06/2020     306   27      6  2020       Freiburg          Schalke 04
#
# ...

# %%
season19 = BLmod[:224]
season19
# Out:
#                     Date  gameno  day  month  year       HomeTeam  \
# 0             16/08/2019       1   16      8  2019  Bayern Munich
# 1             17/08/2019       2   17      8  2019       Dortmund
# 2             17/08/2019       3   17      8  2019      Wolfsburg
# 3             17/08/2019       4   17      8  2019  Werder Bremen
# 4             17/08/2019       5   17      8  2019       Freiburg
# ..                   ...     ...  ...    ...   ...            ...
# 219  2020-07-03 00:00:00     220    7      3  2020       Freiburg
# 220  2020-07-03 00:00:00     221    7      3  2020         Hertha
# 221  2020-08-03 00:00:00     222    8      3  2020  Bayern Munich
# 222  2020-08-03 00:00:00     223    8      3  2020          Mainz
# 223  2020-11-03 00:00:00     224   11      3  2020     M'gladbach
#
#                AwayTeam  FTHG  FTAG FTR  ...  B365D  B365A  Tmhome  Tmaway  \
# 0                Hertha     2     2   D  ...   8.00  15.00  116.05  215.20
# ...

# %%
from bevel.linear_ordinal_regression import OrderedLogit
ol = OrderedLogit()

# %%
ol.fit(season19['lhTMratio'], season19['winvalue'])
ol.print_summary()
# Out:
# n=224
#                   beta  se(beta)      p  lower 0.95  upper 0.95
# attribute names
# column_1        0.5981    0.1129 0.0000      0.3769      0.8193  ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Somers' D = 0.278

# %%
# Predicted probabilities

BLmod['predA'] = 1/(1+np.exp(-(ol.coef_[1]-ol.coef_[0]*BLmod['lhTMratio'])))
BLmod['predD'] = 1/(1+np.exp(-(ol.coef_[2]-ol.coef_[0]*BLmod['lhTMratio']))) - BLmod['predA']
BLmod['predH'] = 1 - BLmod['predA'] - BLmod['predD']

pd.set_option('display.max_columns', 50)
BLmod
# Out:
#            Date  gameno  day  month  year       HomeTeam            AwayTeam  \
# 0    16/08/2019       1   16      8  2019  Bayern Munich              Hertha
# 1    17/08/2019       2   17      8  2019       Dortmund            Augsburg
# 2    17/08/2019       3   17      8  2019      Wolfsburg             FC Koln
# 3    17/08/2019       4   17      8  2019  Werder Bremen  Fortuna Dusseldorf
# 4    17/08/2019       5   17      8  2019       Freiburg               Mainz
# ..          ...     ...  ...    ...   ...            ...                 ...
# 301  27/06/2020     302   27      6  2020       Dortmund          Hoffenheim
# 302  27/06/2020     303   27      6  2020     Leverkusen               Mainz
# 303  27/06/2020     304   27      6  2020  Ein Frankfurt           Paderborn
# 304  27/06/2020     305   27      6  2020       Augsburg          RB Leipzig
# 305  27/06/2020     306   27      6  2020       Freiburg          Schalke 04
#
# ...

# %%
# Result prediction

BLmod['Maxprob'] =BLmod[['predA','predD','predH']].max(axis=1)
BLmod['logitpred']=np.where(BLmod['Maxprob']==BLmod['predA'],'A',\
                               np.where(BLmod['Maxprob']==BLmod['predD'],'D','H'))
BLmod['logittrue']= np.where(BLmod['logitpred'] == BLmod['FTR'],1,0)
BLmod
# Out:
#            Date  gameno  day  month  year       HomeTeam            AwayTeam  \
# 0    16/08/2019       1   16      8  2019  Bayern Munich              Hertha
# 1    17/08/2019       2   17      8  2019       Dortmund            Augsburg
# 2    17/08/2019       3   17      8  2019      Wolfsburg             FC Koln
# 3    17/08/2019       4   17      8  2019  Werder Bremen  Fortuna Dusseldorf
# 4    17/08/2019       5   17      8  2019       Freiburg               Mainz
# ..          ...     ...  ...    ...   ...            ...                 ...
# 301  27/06/2020     302   27      6  2020       Dortmund          Hoffenheim
# 302  27/06/2020     303   27      6  2020     Leverkusen               Mainz
# 303  27/06/2020     304   27      6  2020  Ein Frankfurt           Paderborn
# 304  27/06/2020     305   27      6  2020       Augsburg          RB Leipzig
# 305  27/06/2020     306   27      6  2020       Freiburg          Schalke 04
#
# ...

# %%
trunc19_20 = BLmod[224:].copy()
trunc19_20
# Out:
#            Date  gameno  day  month  year            HomeTeam    AwayTeam  \
# 224  16/05/2020     225   16      5  2020          RB Leipzig    Freiburg
# 225  16/05/2020     226   16      5  2020          Hoffenheim      Hertha
# 226  16/05/2020     227   16      5  2020       Ein Frankfurt  M'gladbach
# 227  16/05/2020     228   16      5  2020  Fortuna Dusseldorf   Paderborn
# 228  16/05/2020     229   16      5  2020            Dortmund  Schalke 04
# ..          ...     ...  ...    ...   ...                 ...         ...
# 301  27/06/2020     302   27      6  2020            Dortmund  Hoffenheim
# 302  27/06/2020     303   27      6  2020          Leverkusen       Mainz
# 303  27/06/2020     304   27      6  2020       Ein Frankfurt   Paderborn
# 304  27/06/2020     305   27      6  2020            Augsburg  RB Leipzig
# 305  27/06/2020     306   27      6  2020            Freiburg  Schalke 04
#
#      FTHG  FTAG FTR  B365H  B365D  B365A  Tmhome  Tmaway   B365HPr   B365DPr  \
# ...

# %%
trunc19_20['B365true']= np.where(trunc19_20['B365res'] == trunc19_20['FTR'],1,0)
trunc19_20
# Out:
#            Date  gameno  day  month  year            HomeTeam    AwayTeam  \
# 224  16/05/2020     225   16      5  2020          RB Leipzig    Freiburg
# 225  16/05/2020     226   16      5  2020          Hoffenheim      Hertha
# 226  16/05/2020     227   16      5  2020       Ein Frankfurt  M'gladbach
# 227  16/05/2020     228   16      5  2020  Fortuna Dusseldorf   Paderborn
# 228  16/05/2020     229   16      5  2020            Dortmund  Schalke 04
# ..          ...     ...  ...    ...   ...                 ...         ...
# 301  27/06/2020     302   27      6  2020            Dortmund  Hoffenheim
# 302  27/06/2020     303   27      6  2020          Leverkusen       Mainz
# 303  27/06/2020     304   27      6  2020       Ein Frankfurt   Paderborn
# 304  27/06/2020     305   27      6  2020            Augsburg  RB Leipzig
# 305  27/06/2020     306   27      6  2020            Freiburg  Schalke 04
#
#      FTHG  FTAG FTR  B365H  B365D  B365A  Tmhome  Tmaway   B365HPr   B365DPr  \
# ...

# %%
trunc19_20['B365true'].mean()
# Out:
# 0.5487804878048781

# %%
trunc19_20['logittrue'].mean()
# Out:
# 0.5

# %%
# Outcome value for calculating Brier Score

trunc19_20['Houtcome']= np.where(trunc19_20['FTR']=='H',1,0)
trunc19_20['Doutcome']= np.where(trunc19_20['FTR']=='D',1,0)
trunc19_20['Aoutcome']= np.where(trunc19_20['FTR']=='A',1,0)
trunc19_20
# Out:
#            Date  gameno  day  month  year            HomeTeam    AwayTeam  \
# 224  16/05/2020     225   16      5  2020          RB Leipzig    Freiburg
# 225  16/05/2020     226   16      5  2020          Hoffenheim      Hertha
# 226  16/05/2020     227   16      5  2020       Ein Frankfurt  M'gladbach
# 227  16/05/2020     228   16      5  2020  Fortuna Dusseldorf   Paderborn
# 228  16/05/2020     229   16      5  2020            Dortmund  Schalke 04
# ..          ...     ...  ...    ...   ...                 ...         ...
# 301  27/06/2020     302   27      6  2020            Dortmund  Hoffenheim
# 302  27/06/2020     303   27      6  2020          Leverkusen       Mainz
# 303  27/06/2020     304   27      6  2020       Ein Frankfurt   Paderborn
# 304  27/06/2020     305   27      6  2020            Augsburg  RB Leipzig
# 305  27/06/2020     306   27      6  2020            Freiburg  Schalke 04
#
#      FTHG  FTAG FTR  B365H  B365D  B365A  Tmhome  Tmaway   B365HPr   B365DPr  \
# ...

# %%
# Model Brier score

Brierlogit = ((trunc19_20['predH'] - trunc19_20['Houtcome'])**2 +(trunc19_20['predD'] - trunc19_20['Doutcome'])**2 +\
             (trunc19_20['predA'] - trunc19_20['Aoutcome'])**2).sum()/82
Brierlogit
# Out:
# 0.5939861306698455

# %%
# Bookie Brier score (lower is better)

BrierB365 = ((trunc19_20['B365HPr'] - trunc19_20['Houtcome'])**2 +(trunc19_20['B365DPr'] - trunc19_20['Doutcome'])**2 +\
             (trunc19_20['B365APr'] - trunc19_20['Aoutcome'])**2).sum()/82
BrierB365
# Out:
# 0.5620787329712247
